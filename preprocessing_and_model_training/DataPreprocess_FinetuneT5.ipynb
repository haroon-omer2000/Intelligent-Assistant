# %%
# !nvidia-smi
# Out:
# Sun Dec 19 14:05:06 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.44       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   33C    P8    28W / 149W |      0MiB / 11441MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
import pandas as pd

# %%
# reading csv file
osama=pd.read_csv("ROCStories__spring2016 - ROCStories_spring2016.csv")

# %%
osama.drop(columns=["storyid"],axis=1,inplace=True)

# %%
osama.head()
# Out:
#           storytitle  ...                                          sentence5
# 0     Overweight Kid  ...             They got themselves and Dan on a diet.
# 1  The Bike Accident  ...  The bike frame bent and Carrie got a deep gash...
# 2              Beach  ...  Her boyfriend was upset he didn't propose to h...
# 3  The bad customer.  ...  Luckily, her coworker intervened and calmed th...
# 4      Being Patient  ...             She asked if we can hang out tomorrow.
#
# [5 rows x 6 columns]

# %%
osama["output"] = osama["sentence1"] + osama["sentence2"]++ osama["sentence3"]+ osama["sentence4"]+ osama["sentence5"]

# %%
osama.head()
# Out:
#           storytitle  ...                                             output
# 0     Overweight Kid  ...  Dan's parents were overweight.Dan was overweig...
# 1  The Bike Accident  ...  Carrie had just learned how to ride a bike.She...
# 2              Beach  ...  Morgan enjoyed long walks on the beach.She and...
# 3  The bad customer.  ...  Jane was working at a diner.Suddenly, a custom...
# 4      Being Patient  ...  I was talking to my crush today.She continued ...
#
# [5 rows x 7 columns]

# %%
osama.drop(columns=["sentence1","sentence2","sentence3","sentence4","sentence5",],axis=1,inplace=True)

# %%
osama = osama.rename(columns={"storytitle":"source_text", "output":"target_text"})
osama = osama[['source_text', 'target_text']]

# %%
osama.head()
# Out:
#          source_text                                        target_text
# 0     Overweight Kid  Dan's parents were overweight.Dan was overweig...
# 1  The Bike Accident  Carrie had just learned how to ride a bike.She...
# 2              Beach  Morgan enjoyed long walks on the beach.She and...
# 3  The bad customer.  Jane was working at a diner.Suddenly, a custom...
# 4      Being Patient  I was talking to my crush today.She continued ...

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
train_df, test_df = train_test_split(osama, test_size=0.2)
train_df.shape, test_df.shape
# Out:
# ((36396, 2), (9100, 2))

# %%
# !pip install simplet5
# Out:
# ...
#      |████████████████████████████████| 1.2 MB 5.3 MB/s
# ...
#      |████████████████████████████████| 2.8 MB 35.0 MB/s
# ...
#      |████████████████████████████████| 919 kB 37.0 MB/s
# ...
#      |████████████████████████████████| 132 kB 44.4 MB/s
# ...
#      |████████████████████████████████| 332 kB 40.7 MB/s
# ...
#      |████████████████████████████████| 596 kB 35.5 MB/s
# ...
#      |████████████████████████████████| 829 kB 46.1 MB/s
# ...
#      |████████████████████████████████| 3.3 MB 24.9 MB/s
# ...
#      |████████████████████████████████| 895 kB 36.3 MB/s
# ...
#      |████████████████████████████████| 61 kB 513 kB/s
# ...
#      |████████████████████████████████| 1.1 MB 47.3 MB/s
# ...
#      |████████████████████████████████| 271 kB 46.7 MB/s
# ...
#      |████████████████████████████████| 160 kB 45.9 MB/s
# ...
#      |████████████████████████████████| 192 kB 46.8 MB/s
# ...
#   Created wheel for simplet5: filename=simplet5-0.1.3-py3-none-any.whl size=6831 sha256=3e8f0ef4aa93f7cd7eaa314f8a0b84fdc9a3263ec2d4fa90ae3becd6b81b5504
# ...

# %%
from simplet5 import SimpleT5
# Out:
# Global seed set to 42

# %%
model = SimpleT5()
model.from_pretrained(model_type="t5", model_name="t5-base")
model.train(train_df=train_df[:32000],
            eval_df=test_df[:1000], 
            source_max_token_len=50, 
            target_max_token_len=300, 
            batch_size=8, max_epochs=2, use_gpu=True)
# Out:
# Downloading:   0%|          | 0.00/792k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.39M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.20k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/892M [00:00<?, ?B/s]
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name  | Type                       | Params
# -----------------------------------------------------
# 0 | model | T5ForConditionalGeneration | 222 M
# -----------------------------------------------------
# 222 M     Trainable params
# 0         Non-trainable params
# 222 M     Total params
# 891.614   Total estimated model params size (MB)
# Validation sanity check: 0it [00:00, ?it/s]
# Global seed set to 42
# Training: -1it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]

# %%
print("ok jee ")
# Out:
# ok jee

# %%
# !pip install simplet5
from simplet5 import SimpleT5
model = SimpleT5()

# %%
# let's load the trained model for inferencing:
model.load_model("t5","/content/outputs/simplet5-epoch-1-train-loss-2.5865", use_gpu=True)
caption_to_story="Osama was driving thr car"
model.predict(caption_to_story)
# Out:
# ['Osama was driving his car.He had a lot of trouble getting to and from school.Osama decided to take a test.Osama passed the test with flying colors.Osama was happy that he got to drive his car.']

# %%
caption_to_story="Shabih was trying to confuse farhan"
model.predict(caption_to_story)
# Out:
# ["Shabih was trying to confuse farhan with a girl.He tried to make her look like a woman, but she didn't understand.Shabih decided to ask her out on a date.She agreed and they had a great time.Shabih ended up having a great time!"]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
model.save_pretrained('./checkpoints/my_checkpoint')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-535b86cf7a50> in <module>()
# ----> 1 model.save_pretrained('./checkpoints/my_checkpoint')
#
# AttributeError: 'SimpleT5' object has no attribute 'save_pretrained'
